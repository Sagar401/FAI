# %% [markdown]
# # Name : Sagar Daswani
#
# ### EAI 6000 - CRN: 21240

# %% [markdown]
# In this lab we will train a neural network model to classify images of clothing.
#
# The lab is designed to be run using Google Colab, but also can be run as a normal jupyter notebook with minor modifications.
#
# This lab uses [tf.keras](https://www.tensorflow.org/guide/keras), a high-level API to build and train models in TensorFlow.

# %%
try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
except Exception:
    pass

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ## Import the Fashion MNIST dataset

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# Examine the dataset size.
# 1. What are the sizes of each image?
# 2. How many categories are there?
# 3. How many images are there in the test and training sets?
# 4. What are the range of values for the images?

# %%
#Ans: 1
print("Sizes of each image: ",train_images[0].shape)
# Out:
# Sizes of each image:  (28, 28)

# %%
#Ans: 2
print("Number of Categories: ",len(np.unique(train_labels)))
# Out:
# Number of Categories:  10

# %%
#Ans: 3
print("Total count of Training +  Test Dataset: ",len(train_images) + len(test_images))
# Out:
# Total count of Training +  Test Dataset:  70000

# %%
#Ans: 4
print("Pixel Values ranges from min = ",train_images.min()," and max = ", train_images.max())
# Out:
# Pixel Values ranges from min =  0  and max =  255

# %% [markdown]
# Preprocess the data by scaling the pixel values of all images to fall between 0 and 1.

# %%
train_images_scaled = train_images / 255
test_images_scaled = test_images / 255

# %% [markdown]
# To verify that the data is in the correct format  display the first 10 images from the *training set* and display the class name below each image.

# %%
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_images_scaled[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# ## Build the model
#
# Using Keras, build a neural network with a single hidden layer consisting of 64 neurons. Remember that you will either have to reshape the image data into 1D vectors, or use a flatten layer at the input.
# 1. Set up the model layers
# 2. Compile the model
# 3. Print the model summary

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(64,activation = 'relu'),
    keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             metrics=['accuracy'])

# %% [markdown]
# ## Train the model
#
# Train the model on the training images for 20 epochs.

# %%
model.fit(train_images, train_labels, epochs=20)
# Out:
# Train on 60000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 11s 182us/sample - loss: 2.2348 - accuracy: 0.6163
# Epoch 2/20
# 60000/60000 [==============================] - 7s 117us/sample - loss: 0.8475 - accuracy: 0.6913
# Epoch 3/20
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.7117 - accuracy: 0.7224
# Epoch 4/20
# 60000/60000 [==============================] - 7s 113us/sample - loss: 0.6635 - accuracy: 0.7366
# Epoch 5/20
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.6448 - accuracy: 0.7409
# Epoch 6/20
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.6086 - accuracy: 0.7658
# Epoch 7/20
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.5911 - accuracy: 0.7833
# Epoch 8/20
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.5591 - accuracy: 0.7927
# Epoch 9/20
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.5633 - accuracy: 0.7928
# Epoch 10/20
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.5569 - accuracy: 0.7957
# Epoch 11/20
# 60000/60000 [==============================] - 7s 115us/sample - loss: 0.5545 - accuracy: 0.7978
# Epoch 12/20
# 60000/60000 [==============================] - 7s 117us/sample - loss: 0.5367 - accuracy: 0.8009
# Epoch 13/20
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.5362 - accuracy: 0.8003
# Epoch 14/20
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.5492 - accuracy: 0.7996
# Epoch 15/20
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.5395 - accuracy: 0.8013
# Epoch 16/20
# 60000/60000 [==============================] - 7s 112us/sample - loss: 0.5318 - accuracy: 0.8027
# Epoch 17/20
# 60000/60000 [==============================] - 7s 113us/sample - loss: 0.5358 - accuracy: 0.8028
# Epoch 18/20
# 60000/60000 [==============================] - 7s 117us/sample - loss: 0.5298 - accuracy: 0.8048
# Epoch 19/20
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.5247 - accuracy: 0.8076
# Epoch 20/20
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.5304 - accuracy: 0.8058

# %% [markdown]
# Evaluate the accuracy of the model on the test dataset. How does it compare with the training accuracy? Is it likely overfitting or underfitting?

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 10000/10000 - 1s - loss: 0.6734 - accuracy: 0.7650
#
# Test accuracy: 0.765

# %% [markdown]
# **ANS**
# Here my training accuracy is arounf 80% where as my test accuracy is close to it with 78% accuracy. Looks like model is good fit, or slightly overfitting as there is difference between training and test accuracy.

# %% [markdown]
# ### Make predictions
#
# The outputs layer of the model contains predictions about the classification for each image.

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])
class_predictions = model.predict_classes(test_images)
prediction_probabilities = probability_model.predict(test_images)

# %%
prediction_probabilities[0]
# Out:
# array([7.3064193e-18, 1.4059275e-18, 0.0000000e+00, 9.5468217e-20,
#        0.0000000e+00, 5.9410769e-02, 0.0000000e+00, 4.0940158e-02,
#        1.4812252e-13, 8.9964908e-01], dtype=float32)

# %%
np.argmax(prediction_probabilities[0])
# Out:
# 9

# %%
prediction_probabilities.shape
# Out:
# (10000, 10)

# %%
class_predictions[0]
# Out:
# 9

# %%
class_predictions.shape
# Out:
# (10000,)

# %% [markdown]
# Examine the shape of the variable 'prediction_probabilities'. How is it different from class_predictions? What do the dimensions correspond to?

# %% [markdown]
# **ANS**  'prediction_probabilities' is an array of probabilities for each category/class. The probability value here represents the "confidence" of possibility for each category predicted by model.
# Whereas, class_predictions is an array of predicted class for test features.
#
# Dimensions for Prediction_probabilites is (10000,10) each row having 10 probability values
#  and dimension for Class_prediction is (10000,) each row with 1 value of its predicted class

# %% [markdown]
# The following functions plot the image and a bar graph of the predicted probabilities. Using these functions, make a plot of the first 25 test images that were incorrectly classified along with their predicted probabilities. Interpret these images - what sort of images tend to be misclassified?

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(np.arange(10),list(class_names),rotation=90)
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)


    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
misclassified = np.where(class_predictions != test_labels)
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i,j in zip(misclassified[0], range(num_images)):
    plt.subplot(num_rows, 2*num_cols, 2*j+1)
    plot_image(i, prediction_probabilities[i], test_labels, test_images)
    plt.subplot(num_rows, 2*num_cols, 2*j+2)
    plot_value_array(i, prediction_probabilities[i], test_labels)
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot a confusion matrix of the predictions. Which misclassifications are the most common?

# %%
con_mat = tf.math.confusion_matrix(labels=test_labels, predictions=class_predictions).numpy()

# %%
con_mat
# Out:
# array([[604,   3,  24,  47,  65,   2, 249,   0,   6,   0],
#        [  0, 950,  17,  22,   7,   0,   3,   0,   1,   0],
#        [  7,   1, 710,   6, 268,   0,   8,   0,   0,   0],
#        [ 12,  23,  14, 786, 127,   0,  37,   0,   1,   0],
#        [  0,   1, 129,  28, 840,   1,   0,   0,   1,   0],
#        [  0,   0,   1,   0,  20, 894,   0,  21,   5,  59],
#        [ 61,   0, 103,  32, 608,   0, 193,   0,   3,   0],
#        [  1,   0,   0,   0,   9,  59,   0, 810,   9, 112],
#        [  0,   0,   4,   3,  67,   3,  27,   2, 893,   1],
#        [  1,   0,   0,   0,   4,  15,   0,  10,   0, 970]])

# %% [markdown]
# **ANS** Looks like many products are being misclassified as coats, such as shirt, bag, pullover. which kinda have similar shapes.

# %%
fig, ax = plt.subplots()
im = ax.imshow(con_mat)
ax.set_xticks(np.arange(10)), ax.set_yticks(np.arange(10))
ax.set_xticklabels(class_names, rotation=45, ha="right")
ax.set_yticklabels(class_names)
ax.set_ylabel('True')
ax.set_xlabel('Predicted')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)

for i in range(100):
    ax.text(int(i/10),i%10,con_mat[i%10,int(i/10)], ha="center", va="center", color="w")
